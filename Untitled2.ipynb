# %%
customers = []

def get_a_number(customers):
    customers.append(len(customers) + 1)

# %%
get_a_number(customers)

# %%
customers
# Out:
# [1, 2, 3]

# %%
def take_a_number(customers):
    customers.pop(0)

# %%
take_a_number(customers)

# %%
customers
# Out:
# []
